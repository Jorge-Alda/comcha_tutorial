# %%
import sys
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from common.readinput import load_data_alps, prepare_sample

# %%
df = prepare_sample(load_data_alps(), seed=42)
df.head()
# Out:
#              fa     cqL33       cuR       cdR     clL33       ceR       chi2  \
# 0  9.548608e+07 -2.182595  2.365146 -0.046695 -2.782481 -1.923896  58.500727
# 1  2.799882e+07  0.075985  1.303429  2.341602 -1.206513  1.901544  18.146333
# 2  7.864249e+07  0.552867  2.366990 -2.300637 -1.003075 -0.883923  18.077660
# 3  8.793040e+07  0.871233  0.245228 -0.611491  0.526986  1.591352  40.457308
# 4  5.559963e+07  0.153850  0.159147 -0.602614  1.859587  1.712885  18.161692
#
#    dofs
# 0    18
# 1    17
# 2    17
# 3    18
# 4    17
